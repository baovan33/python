# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Import dữ liệu**

# %%
data = pd.read_csv("Advertising.csv")
data.head(10)
# Out:
#    Unnamed: 0  Radio  Sales
# 0           1   37.8   22.1
# 1           2   39.3   10.4
# 2           3   45.9    9.3
# 3           4   41.3   18.5
# 4           5   10.8   12.9
# 5           6   48.9    7.2
# 6           7   32.8   11.8
# 7           8   19.6   13.2
# 8           9    2.1    4.8
# 9          10    2.6   10.6

# %%
x = data.values[: , 1]
x
# Out:
# array([37.8, 39.3, 45.9, 41.3, 10.8, 48.9, 32.8, 19.6,  2.1,  2.6,  5.8,
#        24. , 35.1,  7.6, 32.9, 47.7, 36.6, 39.6, 20.5, 23.9, 27.7,  5.1,
#        15.9, 16.9, 12.6,  3.5, 29.3, 16.7, 27.1, 16. , 28.3, 17.4,  1.5,
#        20. ,  1.4,  4.1, 43.8, 49.4, 26.7, 37.7, 22.3, 33.4, 27.7,  8.4,
#        25.7, 22.5,  9.9, 41.5, 15.8, 11.7,  3.1,  9.6, 41.7, 46.2, 28.8,
#        49.4, 28.1, 19.2, 49.6, 29.5,  2. , 42.7, 15.5, 29.6, 42.8,  9.3,
#        24.6, 14.5, 27.5, 43.9, 30.6, 14.3, 33. ,  5.7, 24.6, 43.7,  1.6,
#        28.5, 29.9,  7.7, 26.7,  4.1, 20.3, 44.5, 43. , 18.4, 27.5, 40.6,
#        25.5, 47.8,  4.9,  1.5, 33.5, 36.5, 14. , 31.6,  3.5, 21. , 42.3,
#        41.7,  4.3, 36.3, 10.1, 17.2, 34.3, 46.4, 11. ,  0.3,  0.4, 26.9,
#         8.2, 38. , 15.4, 20.6, 46.8, 35. , 14.3,  0.8, 36.9, 16. , 26.8,
#        21.7,  2.4, 34.6, 32.3, 11.8, 38.9,  0. , 49. , 12. , 39.6,  2.9,
#        27.2, 33.5, 38.6, 47. , 39. , 28.9, 25.9, 43.9, 17. , 35.4, 33.2,
#         5.7, 14.8,  1.9,  7.3, 49. , 40.3, 25.8, 13.9,  8.4, 23.3, 39.7,
#        21.1, 11.6, 43.5,  1.3, 36.9, 18.4, 18.1, 35.8, 18.1, 36.8, 14.7,
#         3.4, 37.6,  5.2, 23.6, 10.6, 11.6, 20.9, 20.1,  7.1,  3.4, 48.9,
#        30.2,  7.8,  2.3, 10. ,  2.6,  5.4,  5.7, 43. , 21.3, 45.1,  2.1,
#        28.7, 13.9, 12.1, 41.1, 10.8,  4.1, 42. , 35.6,  3.7,  4.9,  9.3,
#        42. ,  8.6])

# %%
y = data.values[: , 2]
y
# Out:
# array([22.1, 10.4,  9.3, 18.5, 12.9,  7.2, 11.8, 13.2,  4.8, 10.6,  8.6,
#        17.4,  9.2,  9.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. , 12.5,
#         5.6, 15.5,  9.7, 12. , 15. , 15.9, 18.9, 10.5, 21.4, 11.9,  9.6,
#        17.4,  9.5, 12.8, 25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7, 12.9,
#         8.5, 14.9, 10.6, 23.2, 14.8,  9.7, 11.4, 10.7, 22.6, 21.2, 20.2,
#        23.7,  5.5, 13.2, 23.8, 18.4,  8.1, 24.2, 15.7, 14. , 18. ,  9.3,
#         9.5, 13.4, 18.9, 22.3, 18.3, 12.4,  8.8, 11. , 17. ,  8.7,  6.9,
#        14.2,  5.3, 11. , 11.8, 12.3, 11.3, 13.6, 21.7, 15.2, 12. , 16. ,
#        12.9, 16.7, 11.2,  7.3, 19.4, 22.2, 11.5, 16.9, 11.7, 15.5, 25.4,
#        17.2, 11.7, 23.8, 14.8, 14.7, 20.7, 19.2,  7.2,  8.7,  5.3, 19.8,
#        13.4, 21.8, 14.1, 15.9, 14.6, 12.6, 12.2,  9.4, 15.9,  6.6, 15.5,
#         7. , 11.6, 15.2, 19.7, 10.6,  6.6,  8.8, 24.7,  9.7,  1.6, 12.7,
#         5.7, 19.6, 10.8, 11.6,  9.5, 20.8,  9.6, 20.7, 10.9, 19.2, 20.1,
#        10.4, 11.4, 10.3, 13.2, 25.4, 10.9, 10.1, 16.1, 11.6, 16.6, 19. ,
#        15.6,  3.2, 15.3, 10.1,  7.3, 12.9, 14.4, 13.3, 14.9, 18. , 11.9,
#        11.9,  8. , 12.2, 17.1, 15. ,  8.4, 14.5,  7.6, 11.7, 11.5, 27. ,
#        20.2, 11.7, 11.8, 12.6, 10.5, 12.2,  8.7, 26.2, 17.6, 22.6, 10.3,
#        17.3, 15.9,  6.7, 10.8,  9.9,  5.9, 19.6, 17.3,  7.6,  9.7, 12.8,
#        25.5, 13.4])

# %%
plt.scatter(x, y, marker='o')
x_vals = np.linspace(0, 50, 100)
#plt.plot(x_vals, y_vals(x_vals), color = "red")
plt.xlabel('Radio')
plt.ylabel('Sales')
plt.title('Tập dữ liệu')
plt.show()

# %% [markdown]
# **Code hàm dự đoán**

# %%
def predict(newRadio, weight, bias) :
  return weight*newRadio + bias

# %% [markdown]
# **Code hàm Cost Function**

# %%
def costFunction(x, y, weight, bias) :
  n = len(x)
  sum_err = 0

  for i in range(n):
    sum_err += ( y[i] -(weight * x[i] + bias) )**2

  return sum_err/n

# %% [markdown]
# **Code hàm update weight, bias bằng gradient descent**

# %%
def updateWeight(x, y, weight, bias, learning_rate) :
  n = len(x)
  weight_temp = 0
  bias_temp = 0
  
  for i in range(n) :
    weight_temp += -2 * x[i] * (y[i] - (weight * x[i] + bias))
    bias_temp += -2 * (y[i] - (weight * x[i] + bias))
  
  weight -= ( weight_temp/n ) * learning_rate
  bias -= ( bias_temp/n ) * learning_rate

  return weight, bias

# %% [markdown]
# **Code hàm train**

# %%
def train(x, y, weight, bias, learning_rate, iter) :
  cost_his = []
  for i in range(iter) :
    weight, bias = updateWeight(x, y, weight, bias, learning_rate)
    cost = costFunction(x, y, weight, bias)
    cost_his.append(cost)

  return weight, bias, cost_his

# %% [markdown]
# **Tính ra weight và bias**

# %%
weight, bias, cost = train(x, y, 0.03, 0.0014, 0.001, 50000) #weight, bias , learing_rate là các giá trị ta lựa chọn ngẫu nhiên
print('weight là:')
print(weight)
print('bias là:')
print(bias)
print('CostFunction sau moi lan lap là:')
print(cost)
# Out:
# weight là:
# 0.20249578339253335
# bias là:
# 9.311638095155223
# CostFunction sau moi lan lap là:
# [86.42444871530395, 54.81620707415582, 46.16606399414465, 43.7837062962731, 43.112532699857724, 42.90855123523333, 42.83214120342931, 42.79058316020948, 42.758563860080905, 42.72917253849223, 42.70052246892831, 42.67209853116381, 42.64376006550058, 42.61546864326576, 42.587213745780765, 42.55899247407067, 42.53080400943763, 42.50264810114907, 42.474524653563066, 42.44643361341033, 42.41837493902088, 42.3903485919226, 42.362354534547855, 42.33439272960688, 42.306463139917156, 42.278565728356305, 42.250700457849696, 42.222867291366526, 42.195066191919175, 42.167297122562616, 42.139560046394465, 42.11185492655486, 42.08418172622646, 42.05654040863422, 42.02893093704554, 42.001353274770096, 41.97380738515992, 41.94629323160928, 41.91881077755439, 41.891359986473915, 41.86394082188836, 41.836553247360364, 41.80919722649443, 41.78187272293718, 41.75457970037698, 41.727318122544084, 41.70008795321051, 41.67288915619005, 41.645721695338125, 41.61858553455179, 41.59148063776986, 41.564406968972506, 41.53736449218143, 41.510353171459904, 41.483372970912484, 41.45642385468513, 41.429505786965116, 41.40261873198087, 41.375762654002216, 41.348937517340026, 41.32214328634632, 41.29537992541421, 41.268647398977755, 41.24194567151205, 41.215274707533105, 41.18863447159784, 41.16202492830396, 41.135446042289985, 41.10889777823522, 41.082380100859574, 41.05589297492363, 41.02943636522862, 41.003010236616284, 40.97661455396885, 40.9502492822091, 40.923914386300105, 40.89760983124538, 40.87133558208876, 40.84509160391434, 40.81887786184644, 40.792694321049495, 40.76654094672821, 40.74041770412725, 40.7143245585314, 40.688261475265456, 40.6622284196941, 40.636225357221946, 40.61025225329346, 40.58430907339294, 40.5583957830444, 40.53251234781164, 40.50665873329811, 40.48083490514689, 40.45504082904057, 40.42927647070142, 40.40354179589107, 40.377836770410724, 40.35216136010083, 40.32651553084135, 40.30089924855138, 40.27531247918956, 40.24975518875341, 40.22422734327988, 40.19872890884487, 40.17325985156355, 40.147820137589996, 40.12240973311727, 40.09702860437751, 40.07167671764159, 40.04635403921941, 40.02106053545959, 39.99579617274947, 39.97056091751522, 39.94535473622169, 39.92017759537228, 39.89502946150904, 39.86991030121258, 39.84482008110199, 39.81975876783477, 39.79472632810693, 39.769722728652795, 39.744747936244984, 39.71980191769454, 39.694884639850535, 39.66999606960044, 39.64513617386966, 39.62030491962193, 39.59550227385889, 39.57072820362023, 39.545982675983666, 39.521265658064806, 39.49657711701713, 39.47191702003203, 39.44728533433859, 39.422682027203734, 39.39810706593206, 39.37356041786584, 39.34904205038498, 39.32455193090702, 39.30009002688688, 39.27565630581716, 39.25125073522788, 39.22687328268628, 39.202523915797194, 39.17820260220269, 39.153909309582104, 39.12964400565201, 39.10540665816623, 39.08119723491569, 39.05701570372839, 39.03286203246948, 39.008736189041116, 38.984638141382355, 38.96056785746926, 38.936525305314774, 38.912510452968704, 38.88852326851771, 38.86456372008507, 38.840631775830914, 38.8167274039521, 38.79285057268196, 38.76900125029055, 38.745179405084485, 38.72138500540684, 38.69761801963715, 38.673878416191435, 38.650166163522115, 38.62648123011789, 38.60282358450381, 38.57919319524119, 38.555590030927476, 38.532014060196474, 38.50846525171796, 38.4849435741979, 38.46144899637827, 38.43798148703706, 38.41454101498829, 38.39112754908176, 38.36774105820335, 38.3443815112747, 38.32104887725322, 38.29774312513214, 38.27446422394039, 38.25121214274259, 38.22798685063897, 38.204788316765395, 38.18161651029334, 38.15847140042965, 38.13535295641679, 38.11226114753261, 38.089195943090274, 38.06615731243849, 38.04314522496112, 38.02015965007735, 37.99720055724159, 37.97426791594342, 37.9513616957077, 37.9284818660942, 37.90562839669793, 37.882801257148806, 37.86000041711185, 37.83722584628691, 37.81447751440887, 37.791755391247364, 37.769059446606946, 37.746389650326954, 37.72374597228134, 37.70112838237897,  ...

# %% [markdown]
# Ta có được đường thẳng y = 0.20249578339253335*x + 9.311638095155223

# %%
def y_vals(x):
  return weight*x + bias

# %% [markdown]
# **Vẽ đường thẳng trên tập dữ liệu**

# %%
plt.scatter(x, y, marker='o')
x_vals = np.linspace(0, 50, 100)
plt.plot(x_vals, y_vals(x_vals), color = "red")
plt.xlabel('Radio')
plt.ylabel('Sales')
plt.title('Linear Regression')
plt.show()

# %% [markdown]
# **Vẽ tập hợp các CostFunction sau mỗi lần lặp**

# %%
n = [ i for i in range(50000) ] #50000 lần lặp
plt.plot(n, cost)
plt.show()

# %% [markdown]
# Nhận xét: ta thấy sau mỗi lần lặp thì lỗi nó sẽ giảm đi như vậy thuật toán của ta đang là đúng đắng
